png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_103.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_104.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_105.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_106.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_107.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_108.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_109.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_110.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_111.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_112.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_113.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_114.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_115.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_116.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_117.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_118.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_119.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_120.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_80.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_81.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_82.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_83.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_84.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_85.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_86.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_87.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_88.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_89.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_90.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_91.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_92.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_93.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_94.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_95.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_96.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_97.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_98.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample7_99.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_100.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_101.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_102.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_103.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_104.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_105.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_106.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_107.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_108.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_109.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_110.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_111.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_112.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_113.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_114.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_115.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_116.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_117.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_118.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_119.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_120.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_80.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_81.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_82.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_83.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_84.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_85.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_86.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_87.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_88.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_89.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_90.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_91.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_92.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_93.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_94.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_95.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_96.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_97.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_98.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample8_99.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_100.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_101.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_102.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_103.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_104.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_105.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_106.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_107.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_108.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_109.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_110.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_111.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_112.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_113.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_114.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_115.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_116.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_117.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_118.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_119.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_120.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_80.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_81.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_82.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_83.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_84.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_85.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_86.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_87.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_88.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_89.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_90.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_91.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_92.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_93.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_94.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_95.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_96.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_97.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_98.png
#   inflating: finaldata/Interesting/S6_B246_States3_Interesting_Sample9_99.png

# %%
DATADIR = "./finaldata" 
CATEGORIES = ["Boring", "Interesting"]
#training_data = []
IMG_SIZE = 300 # Hyperparameter. calculated to be stitched together size. each img is 396 x 396. Stitching them together 396*3 = 1188x 1188. So 1185 is an approximation of that.

# %%
## Stitch the images together 
## 0 1 2 
## 3 4 5
## 6 7 8


# the size (e.g. 9) is a hyperparameter
# and the starting point (e.g., 100) is another. so if it's 9, it'd be 100 to 100+9.
import math  
  


def stitch_images(file_path, file_name, start_frame, num_frames):
    images = [Image.open(image) for image in [file_path + "/" + file_name + str(x) + ".png" for x in range(start_frame, start_frame+num_frames)]]
    widths, heights = zip(*(i.size for i in images))
    dimension = int(math.sqrt(num_frames))
    total_width = int(sum(widths) / dimension)
    total_height = int(sum(heights) / dimension)
    new_image = Image.new("RGB", (total_width, total_height))
    for index in range(0, num_frames):
        image = images[index]
        image = image.resize((100, 100))
        new_image.paste(image, ((index % dimension ) * image.size[0], math.floor(index / dimension) * image.size[1]))

    IMAGE_DIR = os.path.join(file_path, "combined/") + file_name + "combined" + str(start_frame) +"and" + str(num_frames) + ".png"
    new_image.save(IMAGE_DIR)
    return IMAGE_DIR

# %%
def create_training_data():
  all_training_data = {} # dict containing training data for hyperparameter configs
  for category in CATEGORIES: 
      path = os.path.join(DATADIR, category)
      class_num = CATEGORIES.index(category)
      for image in sorted(os.listdir(path)): 
          if "100" not in image: ## Find the starting frame
              continue
          for start_frame in [80, 100]:
            for num_frames in [4, 9, 16]:
              training_data = [] 
              IMAGE_DIR = stitch_images(path, image[0:-7], start_frame, num_frames)  # selecting the last 7 character of the file name 
              # The following snippet to reduce data size
              try: 
                  img_array = cv2.imread(IMAGE_DIR, cv2.IMREAD_GRAYSCALE) #cv2.IMREAD_GRAYSCALE: It specifies to load an image in grayscale mode. Alternatively, we can pass integer value 0 for this flag.
                  #new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                  training_data.append([new_array, class_num])
              except Exception as e: 
                  pass 
              all_training_data[(start_frame, num_frames)] = training_data
  return all_training_data

# %%
# Be sure to create two 'combined' folders and put one in each of 'Boring' and 'Interesting'
all_training_data = create_training_data() 

for training_data in all_training_data:
  random.shuffle(training_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-7bc09e9070c7> in <module>()
#       1 # Be sure to create two 'combined' folders and put one in each of 'Boring' and 'Interesting'
#       2
# ----> 3 all_training_data = create_training_data()
#       4
#       5 for training_data in all_training_data:
#
# <ipython-input-46-0ea5b2400ffc> in create_training_data()
#      10             for num_frames in [4, 9, 16]:
#      11               training_data = []
# ---> 12               IMAGE_DIR = stitch_images(path, image[0:-7], start_frame, num_frames)  # selecting the last 7 character of the file name
#      13               # The following snippet to reduce data size
#      14               try:
#
# <ipython-input-45-cea13ce6964c> in stitch_images(file_path, file_name, start_frame, num_frames)
#      20     for index in range(0, num_frames):
#      21         image = images[index]
# ---> 22         image = image.resize((100, 100))
#      23         new_image.paste(image, ((index % dimension ) * image.size[0], math.floor(index / dimension) * image.size[1]))
#      24
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1853         if self.mode in ["LA", "RGBA"]:
#    1854             im = self.convert(self.mode[:-1] + "a")
# -> 1855             im = im.resize(size, resample, box)
#    1856             return im.convert(self.mode)
#    1857
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1871                 )
#    1872
# -> 1873         return self._new(self.im.resize(size, resample, box))
#    1874
#    1875     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:

# %%
X, y = [], []
for features, label in training_data: 
    X.append(features)
    y.append(label)
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1) # -1 automatically changes to the # of instances
y = np.array(y)

# %%
print(X.shape)

# %%
X = X.astype('float32')
X = X / 255.0

# %%
from PIL import Image 
def compute_entropy(signal):
    lensig = signal.size
    symset = list(set(signal))
    numsym = len(symset)
    propab = [np.size(signal[signal == i]) / (1.0 * lensig) for i in symset]
    entropy = np.sum([p * np.log2(1.0 / p) for p in propab])
    return entropy


#
test = X[1].ravel()
print(len(X[1].ravel()))
print(compute_entropy(test))


label_entropies = {'Boring': [], 'Interesting': []}
for i, instance in enumerate(X):
  instance_1d = instance.ravel()
  entropy = compute_entropy(instance_1d)
  label_id = y[i]
  if label_id == 0:
    label_entropies['Boring'].append(entropy)
  else:
    label_entropies['Interesting'].append(entropy)


  # compute_entropy(1d image)
  #

# %%
#label_entropies

import numpy as np
import matplotlib.pyplot as pp
val = 0. # this is the value where you want the data to appear on the y-axis.
ar = label_entropies['Boring'] # just as an example array
pp.plot(ar, np.zeros_like(ar) + val, 'x')
pp.show()
print(min(ar))

# %%
#label_entropies

import numpy as np
import matplotlib.pyplot as pp
val = 0. # this is the value where you want the data to appear on the y-axis.
ar = label_entropies['Interesting'] # just as an example array
pp.plot(ar, np.zeros_like(ar) + val, 'x')
pp.show()

print(min(ar))

# %%
print(np.min(X))
plt.imshow(X[12].reshape(IMG_SIZE, IMG_SIZE), cmap='gray');
plt.axis('off')
plt.savefig('stitched_image.png')
print('Baseline = ', np.sum(y)/len(y) )
print(len(y))

# %%
# Split X, y into training and test data

print(X.shape)
print(X[:2000].shape)
tempx = X[:900]
tempy = y[:900]
X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42)

# %%
# Train on training data only
model2 = keras.Sequential()
model2.add(Conv2D(64, (5, 5), input_shape=tempx.shape[1:]))
model2.add(BatchNormalization())
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.15))

model2.add(Conv2D(64, (3, 3)))
model2.add(BatchNormalization())
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.15))

model2.add(Flatten())
model2.add(Dense(64))
model2.add(Activation("relu"))
model2.add(Dropout(0.15))

model2.add(Dense(10))
model2.add(Activation("relu"))
model2.add(Dropout(0.15))

model2.add(Dense(1))
model2.add(Activation("sigmoid"))

model2.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

with tf.device('/device:GPU:0'):
  model2.fit(X_train, y_train, batch_size=2, epochs=20, verbose = 1)

# %%
# Split X, y into training and test data
#X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42) 

# Reduce positive values to ~10% of data

# Find indices where y_test is interesting
y_test_bool = y_test == 1
num_true = 0
delete_mask = []
for i in range(0, len(y_test)):
  if y_test_bool[i] == True:
    num_true += 1
    if num_true > 15:
      delete_mask.append(i)
      

y_test = np.delete(y_test, delete_mask, 0)
X_test = np.delete(X_test, delete_mask, 0)
print(X_test.shape)
print(np.sum(y_test))

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Do an accuracy test on data with only ~10% interesting claseses
print('Accuracy on test---')
y_pred_test=model2.predict_classes(X_test)
print(accuracy_score(y_test,y_pred_test))
print(recall_score(y_test,y_pred_test))

# %%
# Split X, y into training and test data

print(X.shape)
print(X[:2000].shape)
tempx = X[:1200]
tempy = y[:1200]
X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42)

# %%
# Train on training data only
model3 = keras.Sequential()
model3.add(Conv2D(64, (5, 5), input_shape=tempx.shape[1:]))
model3.add(BatchNormalization())
model3.add(Activation("relu"))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.15))

model3.add(Conv2D(64, (3, 3)))
model3.add(BatchNormalization())
model3.add(Activation("relu"))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.15))

model3.add(Flatten())
model3.add(Dense(64))
model3.add(Activation("relu"))
model3.add(Dropout(0.15))

model3.add(Dense(10))
model3.add(Activation("relu"))
model3.add(Dropout(0.15))

model3.add(Dense(1))
model3.add(Activation("sigmoid"))

model3.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

with tf.device('/device:GPU:0'):
  model3.fit(X_train, y_train, batch_size=2, epochs=20, verbose = 1)

# %%
# Split X, y into training and test data
#X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42) 

# Reduce positive values to ~10% of data

# Find indices where y_test is interesting
y_test_bool = y_test == 1
num_true = 0
delete_mask = []
for i in range(0, len(y_test)):
  if y_test_bool[i] == True:
    num_true += 1
    if num_true > 15:
      delete_mask.append(i)
      

y_test = np.delete(y_test, delete_mask, 0)
X_test = np.delete(X_test, delete_mask, 0)
print(X_test.shape)
print(np.sum(y_test))

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Do an accuracy test on data with only ~10% interesting claseses
print('Accuracy on test---')
y_pred_test=model3.predict_classes(X_test)
print(accuracy_score(y_test,y_pred_test))
print(recall_score(y_test,y_pred_test))

# %%
# Split X, y into training and test data

print(X.shape)
print(X[:2000].shape)
tempx = X[:1500]
tempy = y[:1500]
X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42)

# %%
# Train on training data only
model4 = keras.Sequential()
model4.add(Conv2D(64, (5, 5), input_shape=tempx.shape[1:]))
model4.add(BatchNormalization())
model4.add(Activation("relu"))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.15))

model4.add(Conv2D(64, (3, 3)))
model4.add(BatchNormalization())
model4.add(Activation("relu"))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.15))

model4.add(Flatten())
model4.add(Dense(64))
model4.add(Activation("relu"))
model4.add(Dropout(0.15))

model4.add(Dense(10))
model4.add(Activation("relu"))
model4.add(Dropout(0.15))

model4.add(Dense(1))
model4.add(Activation("sigmoid"))

model4.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

with tf.device('/device:GPU:0'):
  model4.fit(X_train, y_train, batch_size=2, epochs=20, verbose = 1)

# %%
# Split X, y into training and test data
#X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42) 

# Reduce positive values to ~10% of data

# Find indices where y_test is interesting
y_test_bool = y_test == 1
num_true = 0
delete_mask = []
for i in range(0, len(y_test)):
  if y_test_bool[i] == True:
    num_true += 1
    if num_true > 15:
      delete_mask.append(i)
      

y_test = np.delete(y_test, delete_mask, 0)
X_test = np.delete(X_test, delete_mask, 0)
print(X_test.shape)
print(np.sum(y_test))

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Do an accuracy test on data with only ~10% interesting claseses
print('Accuracy on test---')
y_pred_test=model4.predict_classes(X_test)
print(accuracy_score(y_test,y_pred_test))
print(recall_score(y_test,y_pred_test))

# %%
# Split X, y into training and test data

print(X.shape)
print(X[:2000].shape)
tempx = X[:1800]
tempy = y[:1800]
X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42)

# %%
# Train on training data only
model5 = keras.Sequential()
model5.add(Conv2D(64, (5, 5), input_shape=tempx.shape[1:]))
model5.add(BatchNormalization())
model5.add(Activation("relu"))
model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(0.15))

model5.add(Conv2D(64, (3, 3)))
model5.add(BatchNormalization())
model5.add(Activation("relu"))
model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(0.15))

model5.add(Flatten())
model5.add(Dense(64))
model5.add(Activation("relu"))
model5.add(Dropout(0.15))

model5.add(Dense(10))
model5.add(Activation("relu"))
model5.add(Dropout(0.15))

model5.add(Dense(1))
model5.add(Activation("sigmoid"))

model5.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

with tf.device('/device:GPU:0'):
  model5.fit(X_train, y_train, batch_size=2, epochs=20, verbose = 1)

# %%
# Split X, y into training and test data
#X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42) 

# Reduce positive values to ~10% of data

# Find indices where y_test is interesting
y_test_bool = y_test == 1
num_true = 0
delete_mask = []
for i in range(0, len(y_test)):
  if y_test_bool[i] == True:
    num_true += 1
    if num_true > 15:
      delete_mask.append(i)
      

y_test = np.delete(y_test, delete_mask, 0)
X_test = np.delete(X_test, delete_mask, 0)
print(X_test.shape)
print(np.sum(y_test))

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Do an accuracy test on data with only ~10% interesting claseses
print('Accuracy on test---')
y_pred_test=model5.predict_classes(X_test)
print(accuracy_score(y_test,y_pred_test))
print(recall_score(y_test,y_pred_test))

# %%
# Split X, y into training and test data

print(X.shape)
print(X[:2000].shape)
tempx = X[:2100]
tempy = y[:2100]
X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42)

# %%
# Train on training data only
model6 = keras.Sequential()
model6.add(Conv2D(64, (5, 5), input_shape=tempx.shape[1:]))
model6.add(BatchNormalization())
model6.add(Activation("relu"))
model6.add(MaxPooling2D(pool_size=(2, 2)))
model6.add(Dropout(0.15))

model6.add(Conv2D(64, (3, 3)))
model6.add(BatchNormalization())
model6.add(Activation("relu"))
model6.add(MaxPooling2D(pool_size=(2, 2)))
model6.add(Dropout(0.15))

model6.add(Flatten())
model6.add(Dense(64))
model6.add(Activation("relu"))
model6.add(Dropout(0.15))

model6.add(Dense(10))
model6.add(Activation("relu"))
model6.add(Dropout(0.15))

model6.add(Dense(1))
model6.add(Activation("sigmoid"))

model6.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

with tf.device('/device:GPU:0'):
  model6.fit(X_train, y_train, batch_size=2, epochs=20, verbose = 1)

# %%
# Split X, y into training and test data
#X_train, X_test, y_train, y_test = train_test_split(tempx, tempy, test_size = 0.1, random_state = 42) 

# Reduce positive values to ~10% of data

# Find indices where y_test is interesting
y_test_bool = y_test == 1
num_true = 0
delete_mask = []
for i in range(0, len(y_test)):
  if y_test_bool[i] == True:
    num_true += 1
    if num_true > 15:
      delete_mask.append(i)
      

y_test = np.delete(y_test, delete_mask, 0)
X_test = np.delete(X_test, delete_mask, 0)
print(X_test.shape)
print(np.sum(y_test))

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Do an accuracy test on data with only ~10% interesting claseses
print('Accuracy on test---')
y_pred_test=model6.predict_classes(X_test)
print(accuracy_score(y_test,y_pred_test))
print(recall_score(y_test,y_pred_test))
